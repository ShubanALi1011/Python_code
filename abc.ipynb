# %%
print("Hello Wolrd")
# Out:
# Hello Wolrd

# %%
x = 5
y = 6
sum = x+y
print('sum of x and y',sum)
# Out:
# sum of x and y 11

# %%
name = input("Enter name : ")
print("Name : ", name)
# Out:
# Name :  Imran

# %%
no = int(input("enter first number:"))
no1 = int(input("enter second number:"))
sum = no+no1
print("sum of no and no1:",sum)
# Out:
# sum of no and no1: 7

# %%
no = int(input('enter the no '))
if no >= 40:
    print("Pass")
else:
    print("Fail")
